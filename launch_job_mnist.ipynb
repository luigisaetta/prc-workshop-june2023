# %% [markdown]
# ### Launch Jobs for training

# %%
import os
import ads

from ads.jobs import DataScienceJob
from ads.jobs import ScriptRuntime
from ads.jobs import Job

from ads import set_auth

# %%
print(ads.__version__)
# Out:
# 2.8.5

# %%
compartment_id = os.environ['NB_SESSION_COMPARTMENT_OCID']
project_id = os.environ['PROJECT_OCID']

set_auth(auth='resource_principal')

# %%
#
# Here all the definitions
#
LOG_GROUP_ID = "ocid1.loggroup.oc1.eu-frankfurt-1.amaaaaaangencdyazs4l4rzrzsarlej6mqlwlbz6bmnx4adwdlssveam2jaa"
LOG_ID = "ocid1.log.oc1.eu-frankfurt-1.amaaaaaangencdya47httqmxyiew5tkxa6l7gekev2ljpasixuhmp2fa3v5q"

NAMESPACE = "frqap2zhtzbe"
CONDA_BUCKET = "procco-envs"
# bucket with code to execute
SOURCE_BUCKET = "procco-sw"

CUSTOM_ENV_URI = f"oci://{CONDA_BUCKET}@{NAMESPACE}/conda_environments/gpu/prc_pytorch_gpu_/1.0/prc_pytorch_gpu_v1_0"
SOURCE_URI = f"oci://{SOURCE_BUCKET}@{NAMESPACE}/test1.tar.gz"

# the first to execute
RUN_ENTRYPOINT = "train.sh"

# SHAPE_NAME = "VM.Standard2.4"
# SHAPE_NAME = "VM.GPU2.1"
SHAPE_NAME = "VM.GPU.A10.1"
# in GB
STORAGE_SIZE = 2000

JOBS_NAME = "job_mnist_01"

# %%
# 1. Specify the Infrastructure requested
# VM Shape, logging
# network is taken from NB session

# you need to provide the OCID for LogGroup and Log
infrastructure = (
    DataScienceJob()
    .with_shape_name(SHAPE_NAME)
    .with_block_storage_size(STORAGE_SIZE)
    .with_log_group_id(LOG_GROUP_ID)
    .with_log_id(LOG_ID)
)

# %%
# specify the runtime and conda and env 
runtime = (
    ScriptRuntime()
    .with_source(SOURCE_URI)
    .with_custom_conda(CUSTOM_ENV_URI)
    .with_environment_variable(JOB_RUN_ENTRYPOINT=RUN_ENTRYPOINT)
)

# %%
# specify the JOB
job = (
    Job(name=JOBS_NAME)
    .with_infrastructure(infrastructure)
    .with_runtime(runtime)
)

# %%
# create the JOB
job.create()
# Out:
# kind: job
# spec:
#   id: ocid1.datasciencejob.oc1.eu-frankfurt-1.amaaaaaangencdya46azr77xid6lcj6kwdkwbxsb4uvfeyf2j6zwdovrxzpq
#   infrastructure:
#     kind: infrastructure
#     spec:
#       blockStorageSize: 2000
#       compartmentId: ocid1.compartment.oc1..aaaaaaaag2cpni5qj6li5ny6ehuahhepbpveopobooayqfeudqygdtfe6h3a
#       displayName: job_mnist_01
#       jobInfrastructureType: ME_STANDALONE
#       jobType: DEFAULT
#       logGroupId: ocid1.loggroup.oc1.eu-frankfurt-1.amaaaaaangencdyazs4l4rzrzsarlej6mqlwlbz6bmnx4adwdlssveam2jaa
#       logId: ocid1.log.oc1.eu-frankfurt-1.amaaaaaangencdya47httqmxyiew5tkxa6l7gekev2ljpasixuhmp2fa3v5q
#       projectId: ocid1.datascienceproject.oc1.eu-frankfurt-1.amaaaaaangencdyarxbilkubzgqjom3vpr4ejxpp6xtw3blfdvuyhd6sggta
#       shapeName: VM.GPU.A10.2
#     type: dataScienceJob
#   name: job_mnist_01
#   runtime:
#     kind: runtime
#     spec:
#       conda:
#         type: published
#         uri: oci://procco-envs@frqap2zhtzbe/conda_environments/gpu/prc_pytorch_gpu_/1.0/prc_pytorch_gpu_v1_0
#       env:
#       - name: JOB_RUN_ENTRYPOINT
#         value: train.sh
#       scriptPathURI: oci://procco-sw@frqap2zhtzbe/test1.tar.gz
#     type: script

# %%
job_run = job.run()

# %%
job_run.watch()
# Out:
# Job OCID: ocid1.datasciencejob.oc1.eu-frankfurt-1.amaaaaaangencdya46azr77xid6lcj6kwdkwbxsb4uvfeyf2j6zwdovrxzpq
# Job Run OCID: ocid1.datasciencejobrun.oc1.eu-frankfurt-1.amaaaaaangencdyax3zmt6of3yh36ev3qxbxo3vl4slessb6jzvxl67dpkca
# 2023-06-07 13:45:50 - Job Run ACCEPTED
# 2023-06-07 13:46:03 - Job Run ACCEPTED, Infrastructure provisioning.
# 2023-06-07 13:47:43 - Job Run ACCEPTED, Infrastructure provisioned.
# 2023-06-07 13:48:02 - Job Run ACCEPTED, Job run bootstrap starting.
# 2023-06-07 13:51:08 - Job Run ACCEPTED, Job run bootstrap complete. Artifact execution starting.
# 2023-06-07 13:51:23 - Job Run IN_PROGRESS, Job run artifact execution in progress.
# 2023-06-07 13:51:04 - Fontconfig error: Cannot load default config file: No such file: (null)
# 2023-06-07 13:51:07 - GPU available: True (cuda), used: True
# 2023-06-07 13:51:07 - HPU available: False, using: 0 HPUs
# 2023-06-07 13:51:07 - IPU available: False, using: 0 IPUs
# 2023-06-07 13:51:07 - TPU available: False, using: 0 TPU cores
# 100% 9912422/9912422 [00:00<00:00, 355667147.82it/s]
# 100% 28881/28881 [00:00<00:00, 259391207.33it/s]
# 100% 1648877/1648877 [00:00<00:00, 262044990.78it/s]
# 100% 4542/4542 [00:00<00:00, 53663461.32it/s]
# 2023-06-07 13:51:09 - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# 2023-06-07 13:51:09 -   | Name          | Type       | Params
# 2023-06-07 13:51:09 -
# 2023-06-07 13:51:09 - 228 K     Trainable params
# 2023-06-07 13:51:09 - ---------------------------------------------
# 2023-06-07 13:51:09 - 2 | test_accuracy | Accuracy   | 0
# 2023-06-07 13:51:09 - 1 | val_accuracy  | Accuracy   | 0
# 2023-06-07 13:51:09 - 0 | model         | Sequential | 228 K
# 2023-06-07 13:51:09 - ---------------------------------------------
# 2023-06-07 13:51:09 - 0.912     Total estimated model params size (MB)
# 2023-06-07 13:51:09 - 228 K     Total params
# 2023-06-07 13:51:09 - 0         Non-trainable params
# 2023-06-07 13:51:07 - Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# 2023-06-07 13:51:07 - Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# 2023-06-07 13:51:08 - Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
# 2023-06-07 13:51:08 - Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# 2023-06-07 13:51:08 -
# 2023-06-07 13:51:08 - Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# 2023-06-07 13:51:08 - Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# 2023-06-07 13:51:08 -
# 2023-06-07 13:51:08 - Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
# 2023-06-07 13:51:08 - Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# 2023-06-07 13:51:08 - Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
# 2023-06-07 13:51:08 - Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# 2023-06-07 13:51:08 -
# 2023-06-07 13:51:08 - Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# 2023-06-07 13:51:08 -
# 2023-06-07 13:51:08 - Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw
# Epoch 0:  85% 200/235 [00:01<00:00, 142.02it/s, loss=0.315, v_num=0]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 0:  94% 220/235 [00:01<00:00, 130.13it/s, loss=0.315, v_num=0]
# Epoch 0: 100% 235/235 [00:01<00:00, 131.46it/s, loss=0.288, v_num=0, val_loss=0.185, val_acc=0.944]
# Epoch 1:  85% 200/235 [00:01<00:00, 149.84it/s, loss=0.176, v_num=0, val_loss=0.185, val_acc=0.944]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 1:  94% 220/235 [00:01<00:00, 134.96it/s, loss=0.176, v_num=0, val_loss=0.185, val_acc=0.944]
# Epoch 1: 100% 235/235 [00:01<00:00, 135.85it/s, loss=0.166, v_num=0, val_loss=0.0977, val_acc=0.971]
# Epoch 2:  85% 200/235 [00:01<00:00, 148.34it/s, loss=0.136, v_num=0, val_loss=0.0977, val_acc=0.971]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Epoch 2:  94% 220/235 [00:01<00:00, 135.15it/s, loss=0.136, v_num=0, val_loss=0.0977, val_acc=0.971]
# Epoch 2: 100% 235/235 [00:01<00:00, 136.07it/s, loss=0.123, v_num=0, val_loss=0.0694, val_acc=0.979]
# Epoch 3:  85% 200/235 [00:01<00:00, 143.91it/s, loss=0.103, v_num=0, val_loss=0.0694, val_acc=0.979]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 3:  94% 220/235 [00:01<00:00, 131.86it/s, loss=0.103, v_num=0, val_loss=0.0694, val_acc=0.979]
# Epoch 3: 100% 235/235 [00:01<00:00, 132.81it/s, loss=0.1, v_num=0, val_loss=0.0566, val_acc=0.983]
# Epoch 4:  85% 200/235 [00:01<00:00, 147.87it/s, loss=0.0918, v_num=0, val_loss=0.0566, val_acc=0.983]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 4:  94% 220/235 [00:01<00:00, 132.15it/s, loss=0.0918, v_num=0, val_loss=0.0566, val_acc=0.983]
# Epoch 4: 100% 235/235 [00:01<00:00, 131.03it/s, loss=0.0825, v_num=0, val_loss=0.0516, val_acc=0.984]
# Epoch 5:  85% 200/235 [00:01<00:00, 150.33it/s, loss=0.0799, v_num=0, val_loss=0.0516, val_acc=0.984]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 5:  94% 220/235 [00:01<00:00, 135.54it/s, loss=0.0799, v_num=0, val_loss=0.0516, val_acc=0.984]
# Epoch 5: 100% 235/235 [00:01<00:00, 136.21it/s, loss=0.0788, v_num=0, val_loss=0.0434, val_acc=0.987]
# Epoch 6:  85% 200/235 [00:01<00:00, 147.27it/s, loss=0.0764, v_num=0, val_loss=0.0434, val_acc=0.987]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 6:  94% 220/235 [00:01<00:00, 132.18it/s, loss=0.0764, v_num=0, val_loss=0.0434, val_acc=0.987]
# Epoch 6: 100% 235/235 [00:01<00:00, 129.09it/s, loss=0.0702, v_num=0, val_loss=0.0387, val_acc=0.988]
# Epoch 7:  85% 200/235 [00:01<00:00, 145.70it/s, loss=0.0772, v_num=0, val_loss=0.0387, val_acc=0.988]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 7:  94% 220/235 [00:01<00:00, 131.05it/s, loss=0.0772, v_num=0, val_loss=0.0387, val_acc=0.988]
# Epoch 7: 100% 235/235 [00:01<00:00, 133.66it/s, loss=0.0703, v_num=0, val_loss=0.0383, val_acc=0.989]
# Epoch 8:  85% 200/235 [00:01<00:00, 142.83it/s, loss=0.0639, v_num=0, val_loss=0.0383, val_acc=0.989]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 8:  94% 220/235 [00:01<00:00, 128.31it/s, loss=0.0639, v_num=0, val_loss=0.0383, val_acc=0.989]
# Epoch 8: 100% 235/235 [00:01<00:00, 130.94it/s, loss=0.0536, v_num=0, val_loss=0.0336, val_acc=0.989]
# Epoch 9:  85% 200/235 [00:01<00:00, 152.52it/s, loss=0.0606, v_num=0, val_loss=0.0336, val_acc=0.989]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 9:  94% 220/235 [00:01<00:00, 137.66it/s, loss=0.0606, v_num=0, val_loss=0.0336, val_acc=0.989]
# Epoch 9: 100% 235/235 [00:01<00:00, 138.20it/s, loss=0.0599, v_num=0, val_loss=0.0323, val_acc=0.989]
# Epoch 10:  85% 200/235 [00:01<00:00, 141.11it/s, loss=0.0575, v_num=0, val_loss=0.0323, val_acc=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Epoch 10:  94% 220/235 [00:01<00:00, 127.45it/s, loss=0.0575, v_num=0, val_loss=0.0323, val_acc=0.989]
# Epoch 10: 100% 235/235 [00:01<00:00, 126.34it/s, loss=0.0482, v_num=0, val_loss=0.0303, val_acc=0.990]
# Epoch 11:  85% 200/235 [00:01<00:00, 147.64it/s, loss=0.0571, v_num=0, val_loss=0.0303, val_acc=0.990]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 11:  94% 220/235 [00:01<00:00, 130.90it/s, loss=0.0571, v_num=0, val_loss=0.0303, val_acc=0.990]
# Epoch 11: 100% 235/235 [00:01<00:00, 133.65it/s, loss=0.046, v_num=0, val_loss=0.0289, val_acc=0.990]
# Epoch 12:  85% 200/235 [00:01<00:00, 152.04it/s, loss=0.0543, v_num=0, val_loss=0.0289, val_acc=0.990]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 12:  94% 220/235 [00:01<00:00, 134.69it/s, loss=0.0543, v_num=0, val_loss=0.0289, val_acc=0.990]
# Epoch 12: 100% 235/235 [00:01<00:00, 137.28it/s, loss=0.0455, v_num=0, val_loss=0.0287, val_acc=0.989]
# Epoch 13:  85% 200/235 [00:01<00:00, 150.74it/s, loss=0.0496, v_num=0, val_loss=0.0287, val_acc=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Epoch 13:  94% 220/235 [00:01<00:00, 134.97it/s, loss=0.0496, v_num=0, val_loss=0.0287, val_acc=0.989]
# Epoch 13: 100% 235/235 [00:01<00:00, 136.46it/s, loss=0.045, v_num=0, val_loss=0.027, val_acc=0.991]
# Epoch 14:  85% 200/235 [00:01<00:00, 144.39it/s, loss=0.0458, v_num=0, val_loss=0.027, val_acc=0.991]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 14:  94% 220/235 [00:01<00:00, 129.96it/s, loss=0.0458, v_num=0, val_loss=0.027, val_acc=0.991]
# Epoch 14: 100% 235/235 [00:01<00:00, 131.44it/s, loss=0.0457, v_num=0, val_loss=0.027, val_acc=0.991]
# Epoch 15:  85% 200/235 [00:01<00:00, 144.51it/s, loss=0.0463, v_num=0, val_loss=0.027, val_acc=0.991]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Epoch 15:  94% 220/235 [00:01<00:00, 131.29it/s, loss=0.0463, v_num=0, val_loss=0.027, val_acc=0.991]
# Epoch 15: 100% 235/235 [00:01<00:00, 129.47it/s, loss=0.0415, v_num=0, val_loss=0.0252, val_acc=0.992]
# Epoch 16:  85% 200/235 [00:01<00:00, 145.93it/s, loss=0.0399, v_num=0, val_loss=0.0252, val_acc=0.992]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 16:  94% 220/235 [00:01<00:00, 132.10it/s, loss=0.0399, v_num=0, val_loss=0.0252, val_acc=0.992]
# Epoch 16: 100% 235/235 [00:01<00:00, 131.82it/s, loss=0.0398, v_num=0, val_loss=0.024, val_acc=0.992]
# Epoch 17:  85% 200/235 [00:01<00:00, 149.08it/s, loss=0.0396, v_num=0, val_loss=0.024, val_acc=0.992]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 17:  94% 220/235 [00:01<00:00, 132.21it/s, loss=0.0396, v_num=0, val_loss=0.024, val_acc=0.992]
# Epoch 17: 100% 235/235 [00:01<00:00, 134.76it/s, loss=0.0372, v_num=0, val_loss=0.0237, val_acc=0.992]
# Epoch 18:  85% 200/235 [00:01<00:00, 150.78it/s, loss=0.0441, v_num=0, val_loss=0.0237, val_acc=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Epoch 18:  94% 220/235 [00:01<00:00, 134.52it/s, loss=0.0441, v_num=0, val_loss=0.0237, val_acc=0.992]
# Epoch 18: 100% 235/235 [00:01<00:00, 135.23it/s, loss=0.0355, v_num=0, val_loss=0.0238, val_acc=0.992]
# Epoch 19:  85% 200/235 [00:01<00:00, 151.86it/s, loss=0.0346, v_num=0, val_loss=0.0238, val_acc=0.992]
# Validation:   0% 0/20 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 19:  94% 220/235 [00:01<00:00, 136.19it/s, loss=0.0346, v_num=0, val_loss=0.0238, val_acc=0.992]
# Epoch 19: 100% 235/235 [00:01<00:00, 134.46it/s, loss=0.0328, v_num=0, val_loss=0.0221, val_acc=0.993]
# Epoch 19: 100% 235/235 [00:01<00:00, 133.41it/s, loss=0.0328, v_num=0, val_loss=0.0221, val_acc=0.993]
# 2023-06-07 13:51:46 - `Trainer.fit` stopped: `max_epochs=20` reached.
# 2023-06-07 13:51:46 -   rank_zero_warn(
# 2023-06-07 13:51:46 - /home/datascience/conda/prc_pytorch_gpu_v1_0/lib/python3.8/site-packages/pytorch_lightning/trainer/trainer.py:1386: UserWarning: `.test(ckpt_path=None)` was called without a model. The best model of the previous `fit` call will be used. You can pass `.test(ckpt_path='best')` to use the best model or `.test(ckpt_path='last')` to use the last model. If you pass a value, this warning will be silenced.
# 2023-06-07 13:51:46 - Restoring states from the checkpoint path at /home/datascience/checkpoint_mnist/mnist-epoch=19-val_loss=0.02.ckpt
# 2023-06-07 13:51:46 - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# 2023-06-07 13:51:46 - Loaded model weights from checkpoint at /home/datascience/checkpoint_mnist/mnist-epoch=19-val_loss=0.02.ckpt
# 2023-06-07 13:51:47 -        Test metric             DataLoader 0
# 2023-06-07 13:51:47 - ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Testing DataLoader 0: 100% 40/40 [00:00<00:00, 202.40it/s]
# 2023-06-07 13:51:47 - ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# 2023-06-07 13:51:47 -         test_loss          0.019971799105405807
# 2023-06-07 13:51:47 -         test_acc            0.9937000274658203
# 2023-06-07 13:51:47 - ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# 2023-06-07 13:52:10 - Job Run SUCCEEDED, Job run artifact execution in progress.
# kind: jobRun
# spec:
#   id: ocid1.datasciencejobrun.oc1.eu-frankfurt-1.amaaaaaangencdyax3zmt6of3yh36ev3qxbxo3vl4slessb6jzvxl67dpkca
#   infrastructure:
#     kind: infrastructure
#     spec:
#       blockStorageSize: 2000
#       compartmentId: ocid1.compartment.oc1..aaaaaaaag2cpni5qj6li5ny6ehuahhepbpveopobooayqfeudqygdtfe6h3a
#       displayName: job_mnist_01-run-2023-06-07-13:45.48
#       jobInfrastructureType: ME_STANDALONE
#       jobType: DEFAULT
#       logGroupId: ocid1.loggroup.oc1.eu-frankfurt-1.amaaaaaangencdyazs4l4rzrzsarlej6mqlwlbz6bmnx4adwdlssveam2jaa
#       logId: ocid1.log.oc1.eu-frankfurt-1.amaaaaaangencdya47httqmxyiew5tkxa6l7gekev2ljpasixuhmp2fa3v5q
#       projectId: ocid1.datascienceproject.oc1.eu-frankfurt-1.amaaaaaangencdyarxbilkubzgqjom3vpr4ejxpp6xtw3blfdvuyhd6sggta
#       shapeName: VM.GPU.A10.2
#     type: dataScienceJob
#   name: job_mnist_01-run-2023-06-07-13:45.48
#   runtime:
#     kind: runtime
#     spec:
#       conda:
#         region: eu-frankfurt-1
#         type: published
#         uri: oci://procco-envs@frqap2zhtzbe/conda_environments/gpu/prc_pytorch_gpu_/1.0/prc_pytorch_gpu_v1_0
#       definedTags:
#         default-tags:
#           CreatedBy: ocid1.datasciencenotebooksession.oc1.eu-frankfurt-1.amaaaaaangencdya7cpgxfxprffrajesv5qgffbdtnnwoajo75uim3gblyzq
#       entrypoint: train.sh
#       scriptPathURI: test1.tar.gz
#     type: script

# %%
# %%capture --no-stderr cap
job_run.watch()

with open('output1000.txt', 'w') as f:
    f.write(cap.stdout)
